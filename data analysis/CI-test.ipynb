# %% [markdown]
# PILOT STUDY PROPORTION:
#
# 32x32  = 20/30 \
# 64x64 = 21/30 \
# 128x128 = 22/30 \
# 256x256 = 23/30 \
# 512x512 = 20/30 \

# %% [markdown]
# Training RUN TIME :
#
# 32x32 = 0 min 49.3 sec \
# 64x64 = 1 min 13.4 sec \
# 128x128 = 5 min 11,9 sec \
# 256x256 = 11 min 37.1 sec \
# 512x512 = 43 min 14.3 sec

# %%
#runtime in minuttes: 

runtime_32x32 = (49.3 / 60) + 0
runtime_64x64 = (13.4 / 60) + 1 
runtime_128x128 = (11.9 / 60) + 5
runtime_256x256 = (37.1 / 60) + 11 
runtime_512x512 =  (14.6 / 60) + 43

print(f"Training runtime in minuttes for different resolutions: \n32x32: Training runtime = {runtime_32x32:.2f} minuttes  \n64x64: Training runtime = {runtime_64x64:.2f} minuttes \n128x128: Training runtime = {runtime_128x128:.2f} minuttes \n256x256: Training runtime = {runtime_256x256:.2f} minuttes \n512x512: Training runtime = {runtime_512x512:.2f} minuttes ")
# Out:
# Training runtime in minuttes for different resolutions:
# 32x32: Training runtime = 0.82 minuttes
# 64x64: Training runtime = 1.22 minuttes
# 128x128: Training runtime = 5.20 minuttes
# 256x256: Training runtime = 11.62 minuttes
# 512x512: Training runtime = 43.24 minuttes

# %%
import math
z_val = 2.58 
margin_of_error = 0.02

alfa = 0.05 

Bonferroni_corrected_alfa = 0.05 / 5 
print(f"Bonferroni corrected alfa = {Bonferroni_corrected_alfa}")
# Out:
# Bonferroni corrected alfa = 0.01

# %%
# 32x32 

p_32= 20/30 

sample_size_32 = ((z_val**2) *(p_32*(1-p_32)) / margin_of_error**2)
print(sample_size_32)

sample_size_32 = 3699
# Out:
# 3698.0000000000005

# %%
#64x64

p_64 = 21/30
sample_size_64 = ((z_val**2)*(p_64*(1-p_64)) / margin_of_error**2)

print(sample_size_64)
sample_size_64 = 3495
# Out:
# 3494.6100000000006

# %%
#128x128

p_128 = 22/30

sample_size_128 = ((z_val**2)*(p_128*(1-p_128)) / margin_of_error**2 )

print(sample_size_128)

sample_size_128 = 3255
# Out:
# 3254.2400000000007

# %%
#256x256

p_256 = 23/30

sample_size_256 = ((z_val**2)*(p_256*(1-p_256)) / margin_of_error**2 )

print(sample_size_256)

sample_size_256 = 2977
# Out:
# 2976.89

# %%
#512x512 
p_512 = 20/30

sample_size_512 = ((z_val**2)*(p_512*(1-p_512)) / margin_of_error**2 )

print(sample_size_512)

sample_size_512 = 2977
# Out:
# 3698.0000000000005

# %%
# worst case = 3699


pictures_of_each_fruit = 3699/5 
print(round(pictures_of_each_fruit))

n = 740 * 5 
print(n)
# Out:
# 740
# 3700

# %% [markdown]
# FINAL PROPORTION :  \
# 32x32 = 2530/3700 \
# 64x64 = 2686/3700 \
# 128x128 = 2904/3700 \
# 256x256 = 2660/3700\
# 512x512 = 2665/3700

# %%
p_32 = 2530/3700 
p_64 = 2686/3700
p_128 = 2904/3700
p_256 = 2660/3700
p_512 = 2665/3700

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Confidence interval: 32x32

CI_99_32x32_lower = p_32 - z_val * math.sqrt((p_32*(1-p_32)) / n )
CI_99_32x32_higher = p_32 + z_val * math.sqrt((p_32*(1-p_32)) / n )
print(f"CI_99_32x32_lower = {CI_99_32x32_lower:.3f} \nCI_99_32x32_higher = {CI_99_32x32_higher:.3f}")
# Out:
# CI_99_32x32_lower = 0.664
# CI_99_32x32_higher = 0.704

# %%
#Confidence interval: 64x64
#Confidence interval: 32x32

CI_99_64x64_lower = p_64 - z_val * math.sqrt((p_64*(1-p_64)) / n )
CI_99_64x64_higher = p_64 + z_val * math.sqrt((p_64*(1-p_64)) / n )
print(f"CI_99_64x64_lower = {CI_99_64x64_lower:.3f} \nCI_99_64x64_higher = {CI_99_64x64_higher:.3f}")
# Out:
# CI_99_64x64_lower = 0.707
# CI_99_64x64_higher = 0.745

# %%
#Confidence interval: 128x128

CI_99_128x128_lower = p_128 - z_val * math.sqrt((p_128*(1-p_128)) / n )
CI_99_128x128_higher = p_128 + z_val * math.sqrt((p_128*(1-p_128)) / n )
print(f"CI_99_128x128_lower = {CI_99_128x128_lower:.3f} \nCI_99_128x128_higher = {CI_99_128x128_higher:.3f}")
# Out:
# CI_99_128x128_lower = 0.767
# CI_99_128x128_higher = 0.802

# %%
#Confidence interval: 256x256


CI_99_256x256_lower = p_256 - z_val * math.sqrt((p_256*(1-p_256)) / n )
CI_99_256x256_higher = p_256 + z_val * math.sqrt((p_256*(1-p_256)) / n )
print(f"CI_99_256x256_lower = {CI_99_256x256_lower:.3f} \nCI_99_256x256_higher = {CI_99_256x256_higher:.3f}")
# Out:
# CI_99_256x256_lower = 0.700
# CI_99_256x256_higher = 0.738

# %%
#Confidence interval: 512x512


CI_99_512x512_lower = p_512 - z_val * math.sqrt((p_512*(1-p_512)) / n )
CI_99_512x512_higher = p_512 + z_val * math.sqrt((p_512*(1-p_512)) / n )
print(f"CI_99_512x512_lower = {CI_99_512x512_lower:.3f} \nCI_99_512x512_higher = {CI_99_512x512_higher:.3f}")
# Out:
# CI_99_512x512_lower = 0.701
# CI_99_512x512_higher = 0.739

# %% [markdown]
# CI_99_32x32_lower = 0.664
# CI_99_32x32_higher = 0.704
#
# CI_99_64x64_lower = 0.707
# CI_99_64x64_higher = 0.745
#
# CI_99_128x128_lower = 0.767
# CI_99_128x128_higher = 0.802
#
# CI_99_256x256_lower = 0.700
# CI_99_256x256_higher = 0.738
#
# CI_99_512x512_lower = 0.701
# CI_99_512x512_higher = 0.739
